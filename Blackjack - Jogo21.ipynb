# %%
##RASCUNHO

import random

ranks = ['Ás','Dois','Três','Quatro','Cinco','Seis','Sete','Oito','Nove','Dez','Valete','Dama','Rei']
suits = ['Copas','Espadas','Paus','Ouros']
values={'Dois':2,'Três':3,'Quatro':4,'Cinco':5,'Seis':6,'Sete':7,'Oito':8,'Nove':9,'Dez':10,'Valete':10,'Dama':10,'Rei':10,'Ás':11}

class Card:
    def __init__(self, suit, value):
        self.suit = suit
        self.value = value
        
    def __str__(self):
        return self.suit + ' de ' + self.value
        
class Deck:
    def __init__(self):
        self.deck = []
        for name in names:
            for suit in suits:
                self.deck.append(Card(name, suit))
                
    def shuffle(self):
        random.shuffle(self.deck)

    def deal_card(self):
        single_card = self.deck.pop()
        return single_card
    
class Hand:
    def __init__(self):
        self.cards=[]
        self.value = 0

    def add_card(self,card):
        self.cards.append(card)
        self.value += values[card.value]

    
d = Deck()
for i in d.deck:
    print(i)
# Out:
# Ás de Copas
# Ás de Espadas
# Ás de Paus
# Ás de Ouros
# 2 de Copas
# 2 de Espadas
# 2 de Paus
# 2 de Ouros
# 3 de Copas
# 3 de Espadas
# 3 de Paus
# 3 de Ouros
# 4 de Copas
# 4 de Espadas
# 4 de Paus
# 4 de Ouros
# 5 de Copas
# 5 de Espadas
# 5 de Paus
# 5 de Ouros
# 6 de Copas
# 6 de Espadas
# 6 de Paus
# 6 de Ouros
# 7 de Copas
# 7 de Espadas
# 7 de Paus
# 7 de Ouros
# 8 de Copas
# 8 de Espadas
# 8 de Paus
# 8 de Ouros
# 9 de Copas
# 9 de Espadas
# 9 de Paus
# 9 de Ouros
# 10 de Copas
# 10 de Espadas
# 10 de Paus
# 10 de Ouros
# Valete de Copas
# Valete de Espadas
# Valete de Paus
# Valete de Ouros
# Dama de Copas
# Dama de Espadas
# Dama de Paus
# Dama de Ouros
# Rei de Copas
# Rei de Espadas
# Rei de Paus
# Rei de Ouros

# %%
import random

playing = True

ranks = ['Ás','Dois','Três','Quatro','Cinco','Seis','Sete','Oito','Nove','Dez','Valete','Dama','Rei']
suits = ['Copas','Espadas','Paus','Ouros']
values={'Dois':2,'Três':3,'Quatro':4,'Cinco':5,'Seis':6,'Sete':7,'Oito':8,'Nove':9,'Dez':10,'Valete':10,'Dama':10,'Rei':10,'Ás':11}

class Card:
    def __init__(self, rank, suit):
        self.suit = suit
        self.rank = rank
        
    def __str__(self):
        return self.rank + ' de ' + self.suit
        
class Deck:
    def __init__(self):
        self.deck = []
        for rank in ranks:
            for suit in suits:
                self.deck.append(Card(rank, suit))
                
    def shuffle(self):
        random.shuffle(self.deck)

    def deal_card(self):
        single_card = self.deck.pop()
        return single_card
    
class Hand:
    def __init__(self):
        self.cards=[]
        self.value = 0

    def add_card(self, card):
        self.cards.append(card)
        self.value += values[card.rank]

        
def hit(deck, hand):
    single_card = deck.deal_card()
    hand.add_card(single_card)

def hit_or_stand(deck, hand):
    global playing
    while True:
        x = input('\nMais uma carta? Digite s (sim) OU n (não) ')

        if x[0].lower()=='s':
            hit(deck, hand)
        elif x[0].lower()=='n':
            print("Player PAROU\n")
            playing=False
        else:
            print('Digite s ou n!')
            continue

        break

def show_some(player, dealer):
    print('DEALER MÃO: \n')
    print('Uma carta virada!')
    print(dealer.cards[1])
    print('\n')
    print('PLAYER MÃO: \n')
    for card in player.cards:
        print(card)
    print('\n')    
    
def show_all(player, dealer):
    print('DEALER MÃO: \n')
    for card in dealer.cards:
        print(card)
    print('PLAYER MÃO: \n')
    for card in player.cards:
        print(card)
    #print('Pontos: ' + player.value + '\n')
    
def player_busts(player, dealer):
    print('PLAYER PERDEU! DEALER VENCEU!')
    
def player_wins(player, dealer):
    print('PLAYER VENCEU! DEALER PERDEU!')
    
def dealer_busts(player, dealer):
    print('PLAYER VENCEU! DEALER PERDEU!')

def dealer_wins(player, dealer):
    print('PLAYER PERDEU! DEALER VENCEU!')
    
def draw(player, dealer):
    print('EMPATE ENTRE PLAYER E DEALER!')

            
while True:
    print('Início do Blackjack\n')
    deck = Deck()
    deck.shuffle()

    player_hand = Hand()
    player_hand.add_card(deck.deal_card())
    player_hand.add_card(deck.deal_card())

    dealer_hand = Hand()
    dealer_hand.add_card(deck.deal_card())
    dealer_hand.add_card(deck.deal_card())
    
    show_some(player_hand, dealer_hand)

    while playing:
        hit_or_stand(deck, player_hand)
        show_some(player_hand, dealer_hand)
        if player_hand.value > 21:
            player_busts(player_hand, dealer_hand)
            break
    if player_hand.value <= 21:
        while dealer_hand.value < 17:
            hit(deck, dealer_hand)
        show_all(player_hand, dealer_hand)

        if dealer_hand.value > 21:
            dealer_busts(player_hand, dealer_hand)
        elif dealer_hand.value > player_hand.value:
            dealer_wins(player_hand, dealer_hand)
        elif dealer_hand.value < player_hand.value:
            player_wins(player_hand, dealer_hand)
        else:
            draw(player_hand, dealer_hand)

    new_game=input('Gostaria de jogar outra vez? s/n')

    if new_game[0].lower() == 's':
        playing=True
        continue
    else:
        print('\nFim!')
        break
            
#class Play:
    #def __init__(self):
        #self.myDeck = Deck()
    
#d = Deck()
#for i in d.deck:
    #print(i)
# Out:
# Início do Blackjack
#
# DEALER MÃO:
#
# Uma carta virada!
# Quatro de Copas
#
#
# PLAYER MÃO:
#
# Dama de Espadas
# Dama de Ouros
#
#
#
# Mais uma carta? Digite s (sim) OU n (não) n
# Player PAROU
#
# DEALER MÃO:
#
# Uma carta virada!
# Quatro de Copas
#
#
# PLAYER MÃO:
#
# Dama de Espadas
# Dama de Ouros
#
#
# DEALER MÃO:
#
# Sete de Copas
# Quatro de Copas
# Dois de Paus
# Quatro de Espadas
# PLAYER MÃO:
#
# Dama de Espadas
# Dama de Ouros
# PLAYER VENCEU! DEALER PERDEU!
# Gostaria de jogar outra vez? s/nn
# Fim!
